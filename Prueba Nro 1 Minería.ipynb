# %% [markdown]
# # Prueba Nro 1 Minería de Datos

# %% [markdown]
# ## Pronóstico del Clima en Australia

# %% [markdown]
# ### 1. Importación de librerías

# %%
# Importamos la librerías necesarias
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %% [markdown]
# ### 2. Carga de datos desde el Dataset

# %%
dataset_path = './dataset/weatherAUS.csv'
df = pd.read_csv(dataset_path, sep=',')

# %% [markdown]
# ### 3. Mostramos el dataset

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...

# %% [markdown]
# ### 4. Visualizamos la cantidad características y observaciones del dataframe

# %%
df.shape
# Out:
# (142193, 24)

# %% [markdown]
# ### 5. Análisis Estadístico Númerico

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  141556.000000  141871.000000  140787.000000  81350.000000
# mean       12.186400      23.226784       2.349974      5.469824
# std         6.403283       7.117618       8.465173      4.188537
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.800000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  74377.000000  132923.000000  140845.000000  139563.000000
# mean       7.624853      39.984292      14.001988      18.637576
# std        3.781525      13.588801       8.893337       8.803345
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %% [markdown]
# ### 6. Análisis Estadístico ...

# %%
df.describe(include = 'object')
# Out:
#               Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count       142193    142193      132863     132180     138415    140787
# unique        3436        49          16         16         16         2
# top     2014-01-30  Canberra           W          N         SE        No
# freq            49      3418        9780      11393      10663    109332
#
#        RainTomorrow
# count        142193
# unique            2
# top              No
# freq         110316

# %% [markdown]
# ### 7. Verificamos los tipos de datos del Dataframe

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %% [markdown]
# ### 8. Verificación de valores nulos

# %%
for x in df.columns:
    print("La cantidad de valores nulos en la columna : ", x, "Es de", df[x].isna().sum())
# Out:
# La cantidad de valores nulos en la columna :  Date Es de 0
# La cantidad de valores nulos en la columna :  Location Es de 0
# La cantidad de valores nulos en la columna :  MinTemp Es de 637
# La cantidad de valores nulos en la columna :  MaxTemp Es de 322
# La cantidad de valores nulos en la columna :  Rainfall Es de 1406
# La cantidad de valores nulos en la columna :  Evaporation Es de 60843
# La cantidad de valores nulos en la columna :  Sunshine Es de 67816
# La cantidad de valores nulos en la columna :  WindGustDir Es de 9330
# La cantidad de valores nulos en la columna :  WindGustSpeed Es de 9270
# La cantidad de valores nulos en la columna :  WindDir9am Es de 10013
# La cantidad de valores nulos en la columna :  WindDir3pm Es de 3778
# La cantidad de valores nulos en la columna :  WindSpeed9am Es de 1348
# La cantidad de valores nulos en la columna :  WindSpeed3pm Es de 2630
# La cantidad de valores nulos en la columna :  Humidity9am Es de 1774
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustDir       9330
# WindGustSpeed     9270
# WindDir9am       10013
# WindDir3pm        3778
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# RainToday         1406
# RISK_MM              0
# RainTomorrow         0
# dtype: int64

# %% [markdown]
# ### 9. Muestra de características

# %%
for columnas in df.columns:
    print("Nombre de la característica :", columnas)
# Out:
# Nombre de la característica : Date
# Nombre de la característica : Location
# Nombre de la característica : MinTemp
# Nombre de la característica : MaxTemp
# Nombre de la característica : Rainfall
# Nombre de la característica : Evaporation
# Nombre de la característica : Sunshine
# Nombre de la característica : WindGustDir
# Nombre de la característica : WindGustSpeed
# Nombre de la característica : WindDir9am
# Nombre de la característica : WindDir3pm
# Nombre de la característica : WindSpeed9am
# Nombre de la característica : WindSpeed3pm
# Nombre de la característica : Humidity9am
# Nombre de la característica : Humidity3pm
# Nombre de la característica : Pressure9am
# Nombre de la característica : Pressure3pm
# Nombre de la característica : Cloud9am
# Nombre de la característica : Cloud3pm
# Nombre de la característica : Temp9am
# Nombre de la característica : Temp3pm
# Nombre de la característica : RainToday
# Nombre de la característica : RISK_MM
# ...

# %% [markdown]
# ### 10. Creamos un respaldo del Dataframe Original

# %%
df2 = df

# %%
# Eliminamos los nulos del dataframe y mostramos la nueva cantidad de observaciones
df2.dropna().shape[0]
# Out:
# 56420

# %% [markdown]
# ### Evaluamos si es conveniente eliminar los valores nulos
# - Se pierden muchos datos del dataset original
# -

# %%
df2.fillna(-9999, inplace = True)

# %%
df2
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6      -9999.0
# 1       2008-12-02   Albury      7.4     25.1       0.0      -9999.0
# 2       2008-12-03   Albury     12.9     25.7       0.0      -9999.0
# 3       2008-12-04   Albury      9.2     28.0       0.0      -9999.0
# 4       2008-12-05   Albury     17.5     32.3       1.0      -9999.0
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0      -9999.0
# 142189  2017-06-21    Uluru      2.8     23.4       0.0      -9999.0
# 142190  2017-06-22    Uluru      3.6     25.3       0.0      -9999.0
# 142191  2017-06-23    Uluru      5.4     26.9       0.0      -9999.0
# 142192  2017-06-24    Uluru      7.8     27.0       0.0      -9999.0
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...

# %%
df2.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %% [markdown]
# ### 11. Establecemos la variable Objetivo

# %% [markdown]
# - Variable Objetivo **"RainTomorrow"**
# - Responde a la pregunta _**¿llovió al día siguiente, sí o no?**_
# - Esta columna es Sí, si la lluvia de ese día fue de 1 mm o más.

# %%
df2[df2.Location == 'Portland'].groupby('Location')['Location'].count()
# Out:
# Location
# Portland    2996
# Name: Location, dtype: int64

# %%
df2.groupby(df2.Location).size().min()
# Out:
# 1521

# %%
df2.groupby('Location').size().min()
# Out:
# 1521

# %%
# Out:
# C:\Users\jorge\Miniconda3\envs\desafio\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-91-540b609f407b> in <module>
# ----> 1 df2[df2.groupby('Location').size() == df2.groupby('Location').size().min()]
#
# ~\Miniconda3\envs\desafio\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2895         # Do we have a (boolean) 1d indexer?
#    2896         if com.is_bool_indexer(key):
# -> 2897             return self._getitem_bool_array(key)
#    2898
#    2899         # We are left with two options: a single key, and a collection of keys,
#
# ~\Miniconda3\envs\desafio\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
# ...

# %%
df2['Location'].min()
# Out:
# 'Adelaide'

# %%
df2.groupby('Location').count()
# Out:
#                   Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# Location
# Adelaide          3090     3090     3090      3090         3090      3090
# Albany            3016     3016     3016      3016         3016      3016
# Albury            3011     3011     3011      3011         3011      3011
# AliceSprings      3031     3031     3031      3031         3031      3031
# BadgerysCreek     2928     2928     2928      2928         2928      2928
# Ballarat          3028     3028     3028      3028         3028      3028
# Bendigo           3034     3034     3034      3034         3034      3034
# Brisbane          3161     3161     3161      3161         3161      3161
# Cairns            2988     2988     2988      2988         2988      2988
# Canberra          3418     3418     3418      3418         3418      3418
# Cobar             2988     2988     2988      2988         2988      2988
# ...
